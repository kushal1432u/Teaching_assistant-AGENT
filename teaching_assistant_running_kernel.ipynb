# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install streamlit pypdf python-docx groq langchain langchain-groq langgraph scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 93.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.5/329.5 kB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 125.8 MB/s eta 0:00:00
# ...

# %%
# !pip install sentence-transformers faiss-cpu

# %%
# !pip install -q streamlit groq langchain pypdf python-docx scikit-learn

# %%
# !pip install -q langchain-groq langgraph

# %%
# !pip install -q sentence-transformers faiss-cpu

# %%
# !pip install streamlit
# !pip install langchain langchain-groq langchain-core
# !pip install sentence-transformers faiss-cpu
# !pip install pypdf python-docx
# !pip install scikit-learn

# %%
# !pip install streamlit -q
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# !pkill streamlit || echo "No previous Streamlit process"
import time, subprocess

streamlit_proc = subprocess.Popen(["streamlit", "run", "/content/drive/MyDrive/gohak/Teaching_assistant/app3.py", "--server.port", "8501", "--server.headless", "true"])
time.sleep(8)

# Create tunnel
# !cloudflared tunnel --url http://localhost:8501 --no-autoupdate
# Out:
# (Reading database ... 121717 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2025.11.1) over (2025.11.1) ...
# Setting up cloudflared (2025.11.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# 2025-12-07T04:50:28Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-12-07T04:50:28Z INF Requesting new quick Tunnel on trycloudflare.com...
# ...
